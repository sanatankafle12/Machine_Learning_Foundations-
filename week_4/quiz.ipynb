# %% [markdown]
# # CLUSTERING AND SIMILARITY

# %% [markdown]
# ## Question 1:
#
# A country, called Simpleland, has a language with a small vocabulary of just “the”, “on”, “and”, “go”, “round”, “bus”, and “wheels”.  For a word count vector with indices ordered as the words appear above, what is the word count vector for a document that simply says “the wheels on the bus go round and round.”
# Please enter the vector of counts as follows: If the counts were ["the"=1, “on”=3, "and"=2, "go"=1, "round"=2, "bus"=1, "wheels"=1], enter 1321211.
#
# Solution:
# -> We count the words and vectorize as shown in the list. i.e 2 for 'the' 1 for 'on' and so on.. which corresponds to 2111211

# %% [markdown]
# ## Question 2:
#
# In Simpleland, a reader is enjoying a document with a representation: [1 3 2 1 2 1 1].  Which of the following articles would you recommend to this reader next?
#
# Solution:
# Here we are supposed to multiple the both matrixes together and search which results in maximum value as that is the most resembelence.

# %%
lists_of_lists = [[7,0,2,1,0,0,1],
                  [1,7,0,0,2,0,1],
                  [1,0,0,0,7,1,2],
                  [0,2,0,0,7,1,1]]
document = [1,3,2,1,2,1,1]
list_of_weight = []
for j in lists_of_lists:
    weight = 0
    for i in range(len(document)):
        weight= weight + (document[i]*j[i])
    list_of_weight.append(weight)
max_value = max(list_of_weight)
pos = list_of_weight.index(max_value)
print(pos+1)
# Out:
# 2

# %% [markdown]
# Since the value gives position 2 which means the answer is the second option

# %% [markdown]
# ## Question 3:
#
# A corpus in Simpleland has 99 articles.  If you pick one article and perform 1-nearest neighbor search to find the closest article to this query article, how many times must you compute the similarity between two articles?
#
# Solution:
# Since there are 99 articles and we pick one, We are left with 98 articles to compare the chosen article with..
# Hence the answer is 98 or option 1

# %% [markdown]
# ## Question 4:
# For the TF-IDF representation, does the relative importance of words in a document depend on the base of the logarithm used?  For example, take the words "bus" and "wheels" in a particular document.  Is the ratio between the TF-IDF values for "bus" and "wheels" different when computed using log base 2 versus log base 10?

# %%
import math

td_bus = 1/9
td_wheel = 1/9
idf_bus_2 = math.log2(1/9)
idf_wheels_2 = math.log2(1/9)
idf_bus_10 = math.log10(1/9)
idf_wheels_10 = math.log10(1/9)
print((td_bus*idf_bus_2)/(td_wheel*idf_wheels_2)==(td_bus*idf_bus_10)/(td_wheel*idf_wheels_10))
# Out:
# True

# %% [markdown]
# Solution:
#
# No. Log is only used for convenience and log 10 is commonly used but since it is the ratio of presence of a word to the other, it is not affected by the base which can be shown by the above code as well

# %% [markdown]
# ## Question 5:
#
# Which of the following statements are true?  (Check all that apply):
#
# a. Deciding whether an email is spam or not spam using the text of the email and some spam / not spam labels is a supervised learning problem.
#
# b. Dividing emails into two groups based on the text of each email is a supervised learning problem.
#
# c. If we are performing clustering, we typically assume we either do not have or do not use class labels in training the model.

# %% [markdown]
# Solution:
#
# Option 'a' is True as we train it based on labelled emails.
#
# Option 'b' is False as no predefined labels are present to categorize them.
#
# Option 'c' is True as Clustering is unsupervised learning which is based on patterns and structure

# %% [markdown]
# # Question 6:
#
# Which of the following pictures represents the best k-means solution? (Squares represent observations, plus signs are cluster centers, and colors indicate assignments of observations to cluster centers.)
# 1 point
#
#
# a. ![image.png](attachment:image.png)
#
# b. ![image.png](attachment:image-2.png)
#
# c. ![image.png](attachment:image-3.png)

# %% [markdown]
# Solution:
#
# Option 'b' best describes the k-means solution as the center is best situated for all the test values
