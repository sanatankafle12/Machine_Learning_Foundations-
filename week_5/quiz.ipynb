# %% [markdown]
# # Recommender System

# %% [markdown]
# ## Question 1

# %% [markdown]
# Recommending items based on global popularity can (check all that apply):
#
#   a) provide person alization<br>
#   b) capture context (e.g., time of day)<br>
#   c) none of the above
#
# Solution:
#
# c

# %% [markdown]
# ## Question 2

# %% [markdown]
# Recommending items using a classification approach can (check all that apply):<br>
# a) provide personalization<br>
# b) capture context (e.g., time of day)<br>
# c) none of the above

# %% [markdown]
# Solution:
# a,b

# %% [markdown]
# ## Question 3

# %% [markdown]
# Recommending items using a simple count based co-occurrence matrix can (check all that apply)
#
# a) provide personalization<br>
# b) capture context (e.g., time of day)<br>
# c) none of the above

# %% [markdown]
# Solution: a

# %% [markdown]
# ## Question 4

# %% [markdown]
# Recommending items using featurized matrix factorization can (check all that apply):
#
#     a) provide personalization
#     b) capture context (e.g., time of day)
#     c) none of the above

# %% [markdown]
# Solution: a.b

# %% [markdown]
# ## Question 5

# %% [markdown]
# Normalizing co-occurrence matrices is used primarily to account for:
#     <br>a) people who purchased many items
#     <br>b) items purchased by many people
#     c) eliminating rare products

# %% [markdown]
# Solution : b

# %% [markdown]
# ## Question 6

# %% [markdown]
# A store has 3 customers and 3 products. Below are the learned feature vectors for each user and
# product. Based on this estimated model, which product would you recommend most highly to User
# #2?<br>
# User ID Feature vector<br>
# 1 (1.73, 0.01, 5.22)<br>
# 2 (0.03, 4.41, 2.05)<br>
# 3 (1.13, 0.89, 3.76)<br>
# Product ID Feature vector<br>
# 1 (3.29, 3.44, 3.67)<br>
# 2 (0.82, 9.71, 3.88)<br>
# 3 (8.34, 1.72, 0.02)<br><br>
# a) Product #1<br>
# b) Product #2<br>
# c) Product #3

# %% [markdown]
# Solution :b
# [By multiplying the matrixes]

# %% [markdown]
# ## Question 7

# %% [markdown]
# For the liked and recommended items displayed below, calculate the recall and round to 2 decimal
# points. (As in the lesson, green squares indicate recommended items, magenta squares are liked
# items. Items not recommended are grayed out for clarity.) Note: enter your answer in American
# decimal format (e.g. enter 0.98, not 0,98)
#
# <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Soution: 0.33

# %% [markdown]
# ## Question 8

# %% [markdown]
# For the liked and recommended items displayed below, calculate the precision and round to 2
# decimal points. (As in the lesson, green squares indicate recommended items, magenta squares are
# liked items. Items not recommended are grayed out for clarity.) Note: enter your answer in
# American decimal format (e.g. enter 0.98, not 0,98)<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Solution: 0.25

# %% [markdown]
# ## Question 9

# %% [markdown]
# Based on the precision-recall curves in the figure below, which recommender would you use?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# solution : RecSys #1
